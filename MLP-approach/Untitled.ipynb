# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
labels = ["1-Shot", "2-Shot", "4-Shot"]
figure = [84.0, 88.46, 88.46]
bottle = [62.96, 92.59, 96.29]
pen = [55.56,72.22 , 94.4]
guitar = [56.25, 68.75, 75.0]


figure_gk = [53.84, 84.61, 76.92]
bottle_gk = [25.92, 70.30, 100.00]
pen_gk = [33.33,66.79 , 90.40]
guitar_gk = [20.00, 20.00, 65.0]

macc = [64.69, 80.5, 88.5]
macc_gk = [33.27, 60.39, 83.08]

# %%
f = plt.figure(figsize=(16, 12))
X_axis = np.arange(len(labels))
  
plt.plot(X_axis, np.array(macc), label = 'Ours', color = "red")
plt.scatter(X_axis, np.array(macc), s=240, marker='.', color = "red")
plt.plot(X_axis, np.array(macc_gk), label = 'GKNet' , color = "green")
plt.scatter(X_axis, np.array(macc_gk), s=240, marker='.', color = "green")
plt.xticks(X_axis, labels, fontsize=30)
plt.title("mAcc" , fontsize=50)
plt.xlabel("Method" , fontsize=40)
plt.ylabel("Acc%" , fontsize=40)
plt.legend(fontsize=40)
plt.savefig("macc_fig.png")
plt.show()
